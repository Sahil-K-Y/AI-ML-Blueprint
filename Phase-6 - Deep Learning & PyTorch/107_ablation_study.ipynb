# %% [markdown]
# # Day 107 — Ablation Studies & Loss Landscapes
#
# **Phase 6: Deep Learning & PyTorch**
#
# ## 📌 Topics
# - Designing systematic ablation experiments
# - Comparing depth, activations, and regularization
# - Plotting comparative loss curves
