# %% [markdown]
# # Day 110 — Representation Learning Lab
#
# **Phase 6: Deep Learning & PyTorch**
#
# ## 📌 Topics
# - Training Autoencoder on MNIST / Tabular data
# - Extracting latent embeddings
# - Visualizing latent space with t-SNE / PCA
