# %% [markdown]
# # Day 096 — PyTorch Autograd Engine
#
# **Phase 6: Deep Learning & PyTorch**
#
# ## 📌 Topics
# - Dynamic computational graph creation
# - requires_grad=True and .backward()
# - torch.no_grad() context
