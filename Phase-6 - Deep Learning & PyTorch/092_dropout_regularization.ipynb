# %% [markdown]
# # Day 092 — Neural Network Regularization
#
# **Phase 6: Deep Learning & PyTorch**
#
# ## 📌 Topics
# - L1 and L2 weight decay math
# - Inverted Dropout mechanism math
# - Data Augmentation intuition
