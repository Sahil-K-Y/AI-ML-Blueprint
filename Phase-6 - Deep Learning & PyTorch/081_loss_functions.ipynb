# %% [markdown]
# # Day 081 — Deep Learning Loss Functions
#
# **Phase 6: Deep Learning & PyTorch**
#
# ## 📌 Topics
# - MSE, Binary Cross-Entropy (BCE)
# - Categorical Cross-Entropy (CCE), Sparse Cross-Entropy
# - Matching loss functions to task types
