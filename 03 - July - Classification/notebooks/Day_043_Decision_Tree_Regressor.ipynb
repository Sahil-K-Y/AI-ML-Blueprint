# %% [markdown]
# # 📅 Day 043: Decision Tree Regressor
#
# **Description:** Regression trees and split criteria.
#
# **Subtopics to learn:**
#   - Regression splitting (MSE reduction)
#   - DecisionTreeRegressor API
#   - Comparison with Linear Regression
#
# ## 📖 Concept Notes
# > Write your 3-5 key takeaways/notes here.
#
# ## 💻 Code & Practice
# Implement your exercises and tests in this section.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## 🛠️ Build / Submit Task
# Write your main implementation cells below.

# %%
# Your code here

# %% [markdown]
# ## ✅ Verification
# Verify your results and metrics here.

# %%
# Your verification code here
