# %%
import sys
sys.path.append("..")

from src.pipeline import run_pipeline

df_clean = run_pipeline("../data/loan.csv")
# Out:
# 2026-07-01 17:22:49 | pipeline | INFO | ===== Pipeline started =====
# 2026-07-01 17:22:49 | pipeline | INFO | Loading data from ../data/loan.csv
# 2026-07-01 17:22:49 | pipeline | INFO | Data loaded successfully | shape=(614, 13)
# 2026-07-01 17:22:49 | pipeline | WARNING | Missing values detected:
# Gender              13
# Married              3
# Dependents          15
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# dtype: int64
# 2026-07-01 17:22:49 | pipeline | INFO | Filled 'Gender' nulls with mode = Male
# 2026-07-01 17:22:49 | pipeline | INFO | Filled 'Married' nulls with mode = Yes
# 2026-07-01 17:22:49 | pipeline | INFO | Filled 'Dependents' nulls with mode = 0
# 2026-07-01 17:22:49 | pipeline | INFO | Filled 'Self_Employed' nulls with mode = No
# 2026-07-01 17:22:49 | pipeline | INFO | Filled 'LoanAmount' nulls with median = 128.0
# ...
