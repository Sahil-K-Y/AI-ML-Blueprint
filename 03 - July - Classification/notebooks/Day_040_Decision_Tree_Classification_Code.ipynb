# %% [markdown]
# # 📅 Day 040: Decision Tree Classification Code
#
# **Description:** Training and evaluating DecisionTreeClassifier.
#
# **Subtopics to learn:**
#   - DecisionTreeClassifier API
#   - Feature importance metrics
#   - Train/evaluate splits
#
# ## 📖 Concept Notes
# > Write your 3-5 key takeaways/notes here.
#
# ## 💻 Code & Practice
# Implement your exercises and tests in this section.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## 🛠️ Build / Submit Task
# Write your main implementation cells below.

# %%
# Your code here

# %% [markdown]
# ## ✅ Verification
# Verify your results and metrics here.

# %%
# Your verification code here
