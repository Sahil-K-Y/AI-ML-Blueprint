# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Electric_Production.csv')

# %%
df.isnull().sum()
# Out:
# DATE          0
# IPG2211A2N    0
# dtype: int64

# %%
df
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        397 non-null    object
#  1   IPG2211A2N  397 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ KB

# %%
df.describe()
# Out:
#        IPG2211A2N
# count  397.000000
# mean    88.847218
# std     15.387834
# min     55.315100
# 25%     77.105200
# 50%     89.779500
# 75%    100.524400
# max    129.404800

# %%
df.columns
# Out:
# Index(['DATE', 'IPG2211A2N'], dtype='object')

# %%
df_sampoo=pd.read_csv('sales-of-shampoo-over-a-three-ye.csv')

# %%
df_sampoo
# Out:
#     Month  Sales of shampoo over a three year period
# 0   1-Jan                                      266.0
# 1   1-Feb                                      145.9
# 2   1-Mar                                      183.1
# 3   1-Apr                                      119.3
# 4   1-May                                      180.3
# 5   1-Jun                                      168.5
# 6   1-Jul                                      231.8
# 7   1-Aug                                      224.5
# 8   1-Sep                                      192.8
# 9   1-Oct                                      122.9
# 10  1-Nov                                      336.5
# 11  1-Dec                                      185.9
# 12  2-Jan                                      194.3
# 13  2-Feb                                      149.5
# 14  2-Mar                                      210.1
# 15  2-Apr                                      273.3
# 16  2-May                                      191.4
# ...

# %%
df.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151
