# %% [markdown]
# # Day 27: Mini Regression App Planning
# ### Goal: Plan file structure, UI requirements, and integration flow for the Streamlit dashboard.

# %% [markdown]
# ### Proposed File Structure:
# ```text
# Phase-2 - Regression & Streamlit/
# │
# ├── 📁 artifacts/
# │   └── model.joblib                 # Serialized StandardScaler + Lasso model
# ├── 📁 src/
# │   └── predict.py                   # Standalone inference helper script
# ├── house_app.py                     # Streamlit frontend app script
# └── Day 27 - App Planning.md         # Architecture blueprint
# ```

# %%
# Verify the proposed directory structure exists
import os
paths = ['artifacts', 'src', 'house_app.py', 'Day 27 - App Planning.md']
for p in paths:
    exists = os.path.exists(p)
    print(f'{p:<25} : {"FOUND" if exists else "MISSING"}')
